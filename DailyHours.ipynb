# %%
import pandas as pd
import plotly.express as px
import nbformat

# %%
Dinning = pd.read_excel("DinningData.xlsx")

# %%
Dinning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DEP          240 non-null    object
#  1   Semester     240 non-null    object
#  2   Month        240 non-null    int64
#  3   Year         240 non-null    int64
#  4   Hours        180 non-null    float64
#  5   Money Spent  240 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 11.4+ KB

# %%
Dinning.shape
# Out:
# (240, 6)

# %%
Dinning
# Out:
#              DEP Semester  Month  Year    Hours  Money Spent
# 0    Res Dinning     Fall      9  2020  3859.98   31844.8350
# 1    Res Dinning     Fall     10  2020  4722.98   38964.5850
# 2    Res Dinning     Fall     11  2020  2842.68   23452.1100
# 3    Res Dinning     Fall     12  2020  1348.50   11125.1250
# 4    Res Dinning   J-Term      1  2021  2247.99   18545.9175
# ..           ...      ...    ...   ...      ...          ...
# 235     Catering   Spring      4  2024   119.09    1101.5825
# 236     Catering   Spring      5  2024    58.38     540.0150
# 237     Catering   Summer      6  2024     0.00       0.0000
# 238     Catering   Summer      7  2024     0.00       0.0000
# 239     Catering   Summer      8  2024     0.00       0.0000
#
# [240 rows x 6 columns]

# %%
# specifying the column names that I want to use
new_cols_dict ={
    'Money Spent':'Wages',
    'Academic Year':'Academic_Year',
}

Dinning.rename(new_cols_dict, axis=1, inplace=True)

# %%
Dinning.head()
# Out:
#            DEP Semester  Month  Year    Hours       Wages
# 0  Res Dinning     Fall      9  2020  3859.98  31844.8350
# 1  Res Dinning     Fall     10  2020  4722.98  38964.5850
# 2  Res Dinning     Fall     11  2020  2842.68  23452.1100
# 3  Res Dinning     Fall     12  2020  1348.50  11125.1250
# 4  Res Dinning   J-Term      1  2021  2247.99  18545.9175

# %%
Data = pd.DataFrame(Dinning)

# %%
Data
# Out:
#              DEP Semester  Month  Year    Hours       Wages
# 0    Res Dinning     Fall      9  2020  3859.98  31844.8350
# 1    Res Dinning     Fall     10  2020  4722.98  38964.5850
# 2    Res Dinning     Fall     11  2020  2842.68  23452.1100
# 3    Res Dinning     Fall     12  2020  1348.50  11125.1250
# 4    Res Dinning   J-Term      1  2021  2247.99  18545.9175
# ..           ...      ...    ...   ...      ...         ...
# 235     Catering   Spring      4  2024   119.09   1101.5825
# 236     Catering   Spring      5  2024    58.38    540.0150
# 237     Catering   Summer      6  2024     0.00      0.0000
# 238     Catering   Summer      7  2024     0.00      0.0000
# 239     Catering   Summer      8  2024     0.00      0.0000
#
# [240 rows x 6 columns]

# %%
Data.describe().T
# Out:
#        count         mean          std     min       25%      50%         75%  \
# Month  240.0     6.500000     3.459267     1.0     3.750     6.50     9.25000
# Year   240.0  2022.166667     1.215887  2020.0  2021.000  2022.00  2023.00000
# Hours  180.0   491.931611   696.496675     0.0    16.225   264.29   663.59000
# Wages  240.0  3185.846260  5385.814598     0.0     0.000   906.60  4564.18125
#
#              max
# Month     12.000
# Year    2024.000
# Hours   4722.980
# Wages  38964.585

# %%
grouped = Data.groupby(['DEP', 'Academic_Year']).sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 grouped = Data.groupby(['DEP', 'Academic_Year']).sum().reset_index()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Academic_Year'

# %%
grouped
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 grouped
#
# NameError: name 'grouped' is not defined

# %%
def plot_department_wages(dataframe, department):
    dept_data = dataframe.loc[dataframe['DEP'] == department].copy()
    dept_data.loc[:, 'Wages_Rounded'] = dept_data['Wages'].round(0)
    
    fig = px.line(dept_data, x='Academic_Year', y='Wages',
                 title=f'{department} Money Spent in wages by Academic Year',
                 labels= {'Wages': 'Money in wages', 'Academic_Year':'Academic Year'},
                 markers=True,
                 text='Wages_Rounded')
    
    fig.update_traces(textposition='top center')  # Adjust the text position as needed
    fig.update_layout(yaxis=dict(range=[0, dept_data['Wages'].max() + 20000]))

    fig.show()

# %%
# # Getting unique values for departments.


# departments = Data['DEP'].unique()
# for dept in departments:
#     plot_department_wages(grouped, dept)

# %% [markdown]
# #### If you are viewing in github, the graphs are present in the "Wages per year graphs" folder.

# %% [markdown]
# # Wages paid in a year per department

# %%
def plot_year_wages(dataframe, year):
    dept_data = dataframe[dataframe['Academic_Year'] == year]
    fig = px.pie(dept_data, names='DEP', values='Wages',
                 title=f'{year} Money paid in wages',
                 labels= {'Wages': 'Money in wages', 'Academic_Year':'Academic Year'})
    
    fig.update_layout(yaxis=dict(range=[0, dept_data['Wages'].max() + 10000]))

    fig.show()

# %%
# Getting unique values for academic year.

Years = Data['Year'].unique()
Years
# Out:
# array([2020, 2021, 2022, 2023, 2024])

# %%
# # A loop to print graphs for each year.
# # The graphs are saved in the folder "Wages per year graphs" in the same directory as this script.

# for year in Years:
#     plot_year_wages(grouped, year)

# %% [markdown]
# #### If you are viewing in github, the graphs are present in the "Wages per year graphs" folder.

# %% [markdown]
# # Wages paid in a year per department throught the year.

# %%
DatabyMonth = Data.groupby(['DEP','Month', 'Year']).sum().reset_index()

# %%
DatabyMonth
# Out:
#              DEP  Month  Year Semester    Hours       Wages
# 0        C-Store      1  2021   J-Term   104.51    862.2075
# 1        C-Store      1  2022   J-Term     0.00      0.0000
# 2        C-Store      1  2023   J-Term   220.26   2037.4050
# 3        C-Store      1  2024   J-Term   198.52   1836.3100
# 4        C-Store      2  2021   Spring   248.15   2047.2375
# ..           ...    ...   ...      ...      ...         ...
# 235  Res Dinning     11  2023     Fall  1581.20  14626.1000
# 236  Res Dinning     12  2020     Fall  1348.50  11125.1250
# 237  Res Dinning     12  2021     Fall   900.42   7428.4650
# 238  Res Dinning     12  2022     Fall     0.00      0.0000
# 239  Res Dinning     12  2023     Fall   695.89   6436.9825
#
# [240 rows x 6 columns]

# %%
# Function to plot department wages
def plot_department_wages(dataframe, department, month):
    # Filter the DataFrame by department and month
    dept_month_data = dataframe[
        (dataframe['DEP'] == department) & 
        (dataframe['Month'] == month)
    ].copy()
    
    if dept_month_data.empty:
        print(f"No data available for {department} in {month}")
        return
    
    dept_month_data['Wages_Rounded'] = dept_month_data['Wages'].round(1)
    
    fig = px.bar(dept_month_data, x='Year', y='Wages',
                 title=f'{department} - Money Spent on Wages in {month} Over Years',
                 labels={'Wages': 'Money in wages', 'Academic_Year': 'Academic Year'},
                 text='Wages_Rounded')
    
    fig.update_traces(textposition='outside')
    fig.update_layout(yaxis=dict(range=[0, dept_month_data['Wages'].max() + 20000]))

    fig.show()

# %%
# Get unique departments and months
unique_departments = DatabyMonth['DEP'].unique()
unique_months = DatabyMonth['Month'].unique()

# Generate plots for each combination of department and month
for department in unique_departments:
    for month in unique_months:
        plot_department_wages(DatabyMonth, department, month)
